# %% [markdown]
# <a href="https://colab.research.google.com/github/seanirmaai/Sean-AlgoritmaPemrograman/blob/Penugasan-Bab-E/Jobsheet_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM**

# %%
# Praktikum 01 - Tuple: Data Tetap yang Tidak Bisa Diubah

koordinat = (7.05, 110.44)
print("Lintang:", koordinat[0])
print("Bujur:", koordinat[1])
# Out:
# Lintang: 7.05
# Bujur: 110.44

# %%
# Praktikum 02 - Dictionary Dasar: Menyimpan Data Mahasiswa

mahasiswa = {
    "NIM" : "20251001",
    "Nama" : "Andi",
    "Prodi" : "TRK"
}

print("NIM:", mahasiswa["NIM"])
print("Nama:", mahasiswa["Nama"])
print("Prodi:", mahasiswa["Prodi"])
# Out:
# NIM: 20251001
# Nama: Andi
# Prodi: TRK

# %%
# Praktikum 03 - Operasi pada Dictionary

mahasiswa = {
    "NIM" : "20251001",
    "Nama" : "Andi",
    "Prodi" : "TRK"
}

mahasiswa["Umur"] = 20
mahasiswa["Prodi"] = "Teknik Komputer"
del mahasiswa["Umur"]

print(mahasiswa)
# Out:
# {'NIM': '20251001', 'Nama': 'Andi', 'Prodi': 'Teknik Komputer'}

# %%
# Praktikum 04 - Set dan Operasi Himpunan

A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %%
# Praktikum 05 - Studi Kasus: Data Mahsiswa dan Mata Kuliah

mhs1 = {"Algoritma", "Matematika", "Bahasa Inggris"}
mhs2 = {"Algoritma",  "Basis Data", "Matematika"}

print("Mata Kuliah mhs1:", mhs1)
print("Mata Kuliah mhs2:", mhs2)
print("Mata Kuliah yang sama:", mhs1 & mhs2)
# Out:
# Mata Kuliah mhs1: {'Algoritma', 'Matematika', 'Bahasa Inggris'}
# Mata Kuliah mhs2: {'Algoritma', 'Basis Data', 'Matematika'}
# Mata Kuliah yang sama: {'Algoritma', 'Matematika'}

# %%
# Praktikum 06 - Studi Kasus Dictionary: Daftar Nilai Mahasiswa

nilai_mahasiswa = {
    "Andi": 80,
    "Budi": 75,
    "Cici": 90
}

for nama, nilai in nilai_mahasiswa.items():
  print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 80
# Budi: 75
# Cici: 90
# Rata-rata nilai: 81.67

# %% [markdown]
# **PENUGASAN**

# %%
# Penugasan 01 - Tuple Sederhana

data = ("Yislam", 29, "Teknik Industri")

print("Nama:", data[0])
print("Umur:", data[1])
print("Prodi:", data[2])
# Out:
# Nama: Yislam
# Umur: 29
# Prodi: Teknik Industri

# %%
# Penugasan 02 - Tuple Tidak Bisa Diubah

data = (1, 2, 3)

data[1] = 9

print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1314574058.py in <cell line: 0>()
#       3 data = (1, 2, 3)
#       4
# ----> 5 data[1] = 9
#       6
#       7 print(data)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Penugasan 03 - Dictionary Dasar

data = {
    "Judul" : "Algoritma",
    "Penulis" : "Munir",
    "Tahun" : "2021"
}

print("Judul:", data["Judul"])
print("Penulis:", data["Penulis"])
print("Tahun:", data["Tahun"])
# Out:
# Judul: Algoritma
# Penulis: Munir
# Tahun: 2021

# %%
# Penugasan 04 - Operasi Dictionary

dosen = {
    "NIP": "12345",
    "Nama": "Budi",
    "Prodi": "TRK"
}

dosen["Umur"] = 40
dosen["Prodi"] = "Teknik Komputer"
del dosen["Umur"]
print("Data Dosen:", dosen)
# Out:
# Data Dosen: {'NIP': '12345', 'Nama': 'Budi', 'Prodi': 'Teknik Komputer'}

# %%
# Penugasan 05 - Set dan Operasi Himpunan

A = {"Matematika", "Algoritma", "Bahasa Inggris"}
B = {"Algoritma", "Basis Data", "Matematika"}

print("Union (Gabungan):", A | B)
print("Intersection (Irisan):", A & B)
print("Difference (Selisih A - B):", A - B)
# Out:
# Union (Gabungan): {'Bahasa Inggris', 'Algoritma', 'Matematika', 'Basis Data'}
# Intersection (Irisan): {'Matematika', 'Algoritma'}
# Difference (Selisih A - B): {'Bahasa Inggris'}

# %%
# Penugasan 06 - Studi Kasus Dictionary

nilai_mahasiswa = {
    "Andi": 85,
    "Budi": 90,
    "Cici": 78
}

for nama, nilai in nilai_mahasiswa.items():
    print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 85
# Budi: 90
# Cici: 78
# Rata-rata nilai: 84.33

# %%
# Penugasan 07 - Studi Kasus Set – Klub Mahasiswa

klub_A = {"Andi", "Budi", "Cici"}
klub_B = {"Cici", "Deni", "Eka"}

print("Daftar seluruh anggota (Union):", klub_A | klub_B)
print("Anggota di kedua klub (Intersection):", klub_A & klub_B)
print("Anggota hanya di Klub A (Difference):", klub_A - klub_B)
# Out:
# Daftar seluruh anggota (Union): {'Andi', 'Budi', 'Cici', 'Deni', 'Eka'}
# Anggota di kedua klub (Intersection): {'Cici'}
# Anggota hanya di Klub A (Difference): {'Andi', 'Budi'}
