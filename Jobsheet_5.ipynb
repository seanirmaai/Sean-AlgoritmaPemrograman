# %% [markdown]
# <a href="https://colab.research.google.com/github/seanirmaai/Sean-AlgoritmaPemrograman/blob/Penugasan-Bab-E/Jobsheet_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM**

# %% [markdown]
# **Indexing dan Slicing**

# %%
teks = "Politeknik Negeri Semarang"
print(teks[0])
print(teks[0:11])
print(teks[-8:])
# Out:
# P
# Politeknik
# Semarang

# %% [markdown]
# **Method Bawaan String**

# %%
teks = " Politeknik Negeri Semarang "
print(teks.upper ())
print(teks.lower ())
print(teks.title ())
print(teks.strip ())
print(teks.split ())
print("-".join(["Politeknik", "Negeri", "Semarang"]))
# Out:
#  POLITEKNIK NEGERI SEMARANG
#  politeknik negeri semarang
#  Politeknik Negeri Semarang
# Politeknik Negeri Semarang
# ['Politeknik', 'Negeri', 'Semarang']
# Politeknik-Negeri-Semarang

# %% [markdown]
# **Validasi Password**

# %%
password = input("Masukkan password: ")

if password == "phyton123":
  print("Password valid")
elif password == "abc":
  print("Password valid")
else:
  print("Password tidak valid")
# Out:
# Masukkan password: abc
# Password valid

# %% [markdown]
# **String Formating dan F-String**

# %%
nama = "Budi"
umur = 21

print(f"Nama saya {nama}, umur {umur} tahun.")
# Out:
# Nama saya Budi, umur 21 tahun.

# %% [markdown]
# **Operasi dalam F-String**

# %%
a = 10
b = 3

print(f"Hasil penjumlahan {a} + {b} = {a+b}")
print(f"Hasil pembagian {a}/{b} = {a/b:.2f}")
# Out:
# Hasil penjumlahan 10 + 3 = 13
# Hasil pembagian 10/3 = 3.33

# %% [markdown]
# **Casting String**

# %%
angka = 123
teks = "456"

print("Nilai: " + str(angka))
print(int(teks) + 10)
# Out:
# Nilai: 123
# 466

# %% [markdown]
# **Studi Kasus Nyata: Analisis Kalimat**

# %%
kalimat = "Saya kuliah di Politeknik Negeri Semarang"
daftar_kata = kalimat.split(" ")

print(f"Jumlah kata: {len(daftar_kata)}")
for i, kata in enumerate(daftar_kata, start=1):
  print(i, kata)
# Out:
# Jumlah kata: 6
# 1 Saya
# 2 kuliah
# 3 di
# 4 Politeknik
# 5 Negeri
# 6 Semarang

# %% [markdown]
# **PENUGASAN**

# %% [markdown]
# **Indexing dan Slicing**

# %%
teks = "Politeknik Negeri Semarang"
print(teks[0])
print(teks[-1])
print(teks[11:17])
# Out:
# P
# g
# Negeri

# %% [markdown]
# **Manipulasi String**

# %%
teks = input("Masukkan sebuah kalimat: ")

print(teks.upper ())
print(teks.lower ())
print(len(teks))
# Out:
# Masukkan sebuah kalimat: Masihkah unggu muda? warna langit
# MASIHKAH UNGGU MUDA? WARNA LANGIT
# masihkah unggu muda? warna langit
# 33

# %% [markdown]
# **Validasi Username**

# %%
username = input("Masukkan username: ")

if " " in username:
  print("Eror! Username tidak boleh mengandung spasi")
else:
  print("Username valid")
# Out:
# Masukkan username: password ini1 2
# Eror! Username tidak boleh mengandung spasi

# %% [markdown]
# **String Formatting dengan F-String**

# %%
nama = "Andi"
umur = 20
jurusan = "Teknologi Rekayasa Komputer"

print(f" Nama: {nama}\n Umur: {umur}\n Jurusan: {jurusan}")
# Out:
#  Nama: Andi
#  Umur: 20
#  Jurusan: Teknologi Rekayasa Komputer

# %% [markdown]
# **Operasi dalam F-String**

# %%
a = int(input("Masukkan bilangan 1: "))
b = int(input("Masukkan bilangin 2:"))

print(f"Hasil penjumlahan {a} + {b} = {a+b}")
print(f"Hasil perkalian {a} * {b} = {a * b}")
print(f"Hasil pembagian {a}/{b} = {a/b:.3f}")
# Out:
# Masukkan bilangan 1: 21
# Masukkan bilangin 2:7
# Hasil penjumlahan 21 + 7 = 28
# Hasil perkalian 21 * 7 = 147
# Hasil pembagian 21/7 = 3.000

# %% [markdown]
# **Casting Data**

# %%
angka_str = input("Masukkan sebuah angka (string): ")

angka_int = int(angka_str)
print(f"Kuadrat dari {angka_int} adalah {angka_int ** 2}")

angka_float = float(angka_str)
print(f"Sebagai float: {angka_float:.2f}")
# Out:
# Masukkan sebuah angka (string): 7
# Kuadrat dari 7 adalah 49
# Sebagai float: 7.00

# %% [markdown]
# **Studi Kasus - Analisis Teks**

# %%
kalimat = input("Masukkan sebuah kalimat: ")

daftar_kata = kalimat.split()

print(f"Jumlah kata: {len(daftar_kata)}")

kata_terpanjang = max(daftar_kata, key=len)
print(f"Kata terpanjang: {kata_terpanjang}")

print("Daftar kata urut abjad:")
for kata in sorted(daftar_kata):
    print("-", kata)
# Out:
# Masukkan sebuah kalimat: mondereul annyeong
# Jumlah kata: 2
# Kata terpanjang: mondereul
# Daftar kata urut abjad:
# - annyeong
# - mondereul
